# %% [markdown]
# <a href="https://colab.research.google.com/github/Tnfix/Tnfix/blob/main/pandas_for_csv_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # importing pandas library coz this is gonna help us manipulate daa in our csv file.

# %%
df = pd.read_csv('Walmart.csv') # Pandas read the csv file in your working directory or dedicated url

# %%
df.head(6) #preview the dataframe 1st 6 rows
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
# 5      1  12-03-2010    1439541.59             0        57.79       2.667
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106
# 5  211.380643         8.106

# %%
df.tail(4) #preview the dataframe last 4 rows
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667

# %%
df #display values in all cells of the dataframe
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df.shape # display (rows, columns)
# Out:
# (6435, 8)

# %%
df.size # display number of cells in the dataframe i.e (rows * columns)
# Out:
# 51480

# %%
len(df) # display number of rows in dataframe
# Out:
# 6435

# %%
df.columns # display a list of collumns in the array
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
df.columns[4] # display specific column. As per index
# Out:
# 'Temperature'

# %%
df['Temperature'] # Extracting values of a specific column.
# Out:
# 0       42.31
# 1       38.51
# 2       39.93
# 3       46.63
# 4       46.50
#         ...
# 6430    64.88
# 6431    64.89
# 6432    54.47
# 6433    56.47
# 6434    58.85
# Name: Temperature, Length: 6435, dtype: float64

# %%
df['Temperature'][:7] # Extraxt 1st 7 values in a dataframe collumn.
# Out:
# 0    42.31
# 1    38.51
# 2    39.93
# 3    46.63
# 4    46.50
# 5    57.79
# 6    54.58
# Name: Temperature, dtype: float64

# %%
df['Temperature'][2:7] # Extract data from 3rd row to 7th row  **Indexing observed**
# Out:
# 2    39.93
# 3    46.63
# 4    46.50
# 5    57.79
# 6    54.58
# Name: Temperature, dtype: float64

# %%
df['Temperature'][7] # Extract value in cell (7, Temperature) **indexing observed**
# Out:
# 51.45

# %%
df[['Temperature', 'Date']] # Extract values in two collumns
# Out:
#       Temperature        Date
# 0           42.31  05-02-2010
# 1           38.51  12-02-2010
# 2           39.93  19-02-2010
# 3           46.63  26-02-2010
# 4           46.50  05-03-2010
# ...           ...         ...
# 6430        64.88  28-09-2012
# 6431        64.89  05-10-2012
# 6432        54.47  12-10-2012
# 6433        56.47  19-10-2012
# 6434        58.85  26-10-2012
#
# [6435 rows x 2 columns]

# %%
df[['Temperature', 'Date']][:4] # Display 1st 4
# Out:
#    Temperature        Date
# 0        42.31  05-02-2010
# 1        38.51  12-02-2010
# 2        39.93  19-02-2010
# 3        46.63  26-02-2010

# %%
df.sort_values(['Temperature']) # Sorts whole csv file according to specified collumn 'Temperature in our case' from least to highest.
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 910       7  04-02-2011     558027.77             0        -2.06       3.011
# 3626     26  28-01-2011     817485.14             0         5.54       3.243
# 2336     17  07-01-2011    1083071.14             0         6.23       2.891
# 959       7  13-01-2012     593875.46             0         7.46       3.077
# 5628     40  28-01-2011     775910.43             0         9.51       3.243
# ...     ...         ...           ...           ...          ...         ...
# 1597     12  23-07-2010     912403.67             0        99.22       3.112
# 5315     38  23-07-2010     328336.85             0        99.22       3.112
# 4657     33  26-08-2011     237095.82             0        99.66       3.663
# 4707     33  10-08-2012     297753.49             0       100.07       3.811
# 4599     33  16-07-2010     280937.84             0       100.14       2.971
#
#              CPI  Unemployment
# ...

# %%
val_count = df['Temperature'].value_counts() # Sorts by number of occurrnces of a value th the dataset row, Temperature in our case.
val_count  # Call variable to display values.
# Out:
# 50.43    11
# 67.87    10
# 76.67     9
# 76.03     9
# 70.28     9
#          ..
# 34.93     1
# 38.53     1
# 41.10     1
# 45.54     1
# 74.09     1
# Name: Temperature, Length: 3528, dtype: int64

# %%
val_count.plot(kind = 'bar')
